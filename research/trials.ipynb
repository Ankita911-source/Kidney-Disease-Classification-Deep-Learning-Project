# %%
# config box
d = {"key":"val", "key1":"val1"}

# %%
d['key1']
# Out:
# 'val1'

# %%
d.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 d.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"Key":"val", "key1":"val1"})

# %%
d2.key1
# Out:
# 'val1'

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %%
type(d)
# Out:
# dict

# %%
# ensure annotations 

def get_product(x:int, y:int) -> int:
    return x*y

# %%
get_product(x=2, y=3)
# Out:
# 6

# %%
get_product(x=2, y="3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int, y:int) -> int:
    return x*y

# %%
get_product(x=2, y=3)
# Out:
# 6

# %%
get_product(x=2, y="3")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 get_product(x=2, y="3")
#
# File d:\DataScience\Kidney-Disease-Classification-Deep-Learning-Project\venv1\lib\site-packages\ensure\main.py:845, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     840     if not isinstance(value, templ):
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
# --> 845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
#     849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x0000022426358C10> does not match annotation type <class 'int'>

# %% [markdown]
# Download data from gdrive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1Z1TpwO6CljFL1aCiqmACCl19tAh9hUvU/view?usp=sharing"

# %%
url.split("/")
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'file',
#  'd',
#  '1Z1TpwO6CljFL1aCiqmACCl19tAh9hUvU',
#  'view?usp=sharing']

# %%
file_id = url.split("/")[-2]

# %%
file_id
# Out:
# '1Z1TpwO6CljFL1aCiqmACCl19tAh9hUvU'

# %%
prefix = 'https://drive.google.com/uc?export=download&id='
gdown.download(prefix+file_id, "kidney-normal-tumor.zip", quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Z1TpwO6CljFL1aCiqmACCl19tAh9hUvU
# From (redirected): https://drive.google.com/uc?id=1Z1TpwO6CljFL1aCiqmACCl19tAh9hUvU&confirm=t&uuid=42a4978b-ad78-4ebd-a4ed-1db0c17c8771
# To: d:\DataScience\Kidney-Disease-Classification-Deep-Learning-Project\research\kidney-normal-tumor.zip
# 100%|██████████| 941M/941M [12:44<00:00, 1.23MB/s]
# 'kidney-normal-tumor.zip'
